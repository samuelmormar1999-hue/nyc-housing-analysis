# %%
import pandas as pd 

df = pd.read_csv("../data/nyc_housing_base.csv")

df.head()
# Out:
#    borough_x  block  lot  sale_price  zip_code borough_y  yearbuilt  lotarea  \
# 0          1    400   11      280000   10009.0        MN     1900.0   2404.0
# 1          1    402   36     2000000   10009.0        MN     1900.0   1919.0
# 2          1    402   60     3400000   10009.0        MN     1920.0   2150.0
# 3          1    404   42     4000000   10009.0        MN     1855.0   2369.0
# 4          1    372   55      655000   10009.0        MN     1920.0   5298.0
#
#    bldgarea  resarea  comarea  unitsres  unitstotal  numfloors   latitude  \
# 0    6875.0   6875.0      0.0      18.0        18.0        5.0  40.724415
# 1    7810.0   6810.0   1000.0       8.0        10.0        5.0  40.724975
# 2    6152.0   5352.0    800.0       8.0         9.0        5.0  40.725346
# 3    6990.0   6990.0      0.0      10.0        10.0        5.0  40.727398
# 4   17990.0  17990.0      0.0      20.0        20.0        5.0  40.720621
#
#    longitude  landuse bldgclass  building_age
# 0 -73.983891      2.0        C6         125.0
# 1 -73.981535      2.0        C4         125.0
# 2 -73.983112      4.0        C7         105.0
# 3 -73.980600      2.0        C4         170.0
# 4 -73.979534      2.0        C6         105.0

# %%
df.shape
# Out:
# (34439, 19)

# %%
df.columns
# Out:
# Index(['borough_x', 'block', 'lot', 'sale_price', 'zip_code', 'borough_y',
#        'yearbuilt', 'lotarea', 'bldgarea', 'resarea', 'comarea', 'unitsres',
#        'unitstotal', 'numfloors', 'latitude', 'longitude', 'landuse',
#        'bldgclass', 'building_age'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34439 entries, 0 to 34438
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   borough_x     34439 non-null  int64
#  1   block         34439 non-null  int64
#  2   lot           34439 non-null  int64
#  3   sale_price    34439 non-null  int64
#  4   zip_code      34423 non-null  float64
#  5   borough_y     34439 non-null  object
#  6   yearbuilt     34439 non-null  float64
#  7   lotarea       34439 non-null  float64
#  8   bldgarea      34439 non-null  float64
#  9   resarea       34251 non-null  float64
#  10  comarea       34251 non-null  float64
#  11  unitsres      34439 non-null  float64
#  12  unitstotal    34439 non-null  float64
#  13  numfloors     34396 non-null  float64
#  14  latitude      34433 non-null  float64
#  15  longitude     34433 non-null  float64
#  16  landuse       34436 non-null  float64
#  17  bldgclass     34439 non-null  object
#  18  building_age  34439 non-null  float64
# dtypes: float64(13), int64(4), object(2)
# memory usage: 5.0+ MB

# %%
df.dtypes
# Out:
# borough_x         int64
# block             int64
# lot               int64
# sale_price        int64
# zip_code        float64
# borough_y        object
# yearbuilt       float64
# lotarea         float64
# bldgarea        float64
# resarea         float64
# comarea         float64
# unitsres        float64
# unitstotal      float64
# numfloors       float64
# latitude        float64
# longitude       float64
# landuse         float64
# bldgclass        object
# building_age    float64
# dtype: object

# %%
df.describe()
# Out:
#           borough_x         block           lot    sale_price      zip_code  \
# count  34439.000000  34439.000000  34439.000000  3.443900e+04  34423.000000
# mean       3.073608   4562.694532     60.057174  1.171832e+06  10866.464370
# std        1.287072   3611.017542    136.516558  1.241375e+06    557.770632
# min        1.000000      1.000000      1.000000  1.186300e+04  10001.000000
# 25%        2.000000   1432.000000     14.000000  5.125000e+05  10308.000000
# 50%        3.000000   3854.000000     33.000000  8.250000e+05  11210.000000
# 75%        4.000000   6678.000000     59.000000  1.300000e+06  11364.000000
# max        5.000000  16350.000000   3635.000000  9.995000e+06  11697.000000
#
#           yearbuilt       lotarea      bldgarea       resarea       comarea  \
# count  34439.000000  3.443900e+04  3.443900e+04  3.425100e+04  3.425100e+04
# mean    1941.007579  5.244022e+04  6.271570e+04  5.593040e+04  6.846554e+03
# std       28.985203  5.032042e+05  2.712663e+05  2.116029e+05  6.971171e+04
# min     1800.000000  1.610000e+02  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     1920.000000  2.090000e+03  1.614500e+03  1.356000e+03  0.000000e+00
# 50%     1935.000000  3.090000e+03  2.494000e+03  2.120000e+03  0.000000e+00
# 75%     1960.000000  7.502000e+03  1.450000e+04  9.816000e+03  0.000000e+00
# max     2025.000000  2.225160e+07  3.750565e+06  2.690565e+06  1.100000e+06
#
#            unitsres    unitstotal     numfloors      latitude     longitude  \
# count  34439.000000  34439.000000  34396.000000  34433.000000  34433.000000
# mean      51.716775     52.309765      4.227674     40.707342    -73.919829
# std      173.385339    174.964326      5.230538      0.082194      0.108336
# min        0.000000      0.000000      1.000000     40.500291    -74.253599
# 25%        1.000000      1.000000      2.000000     40.640011    -73.978330
# 50%        2.000000      2.000000      2.000000     40.705836    -73.915430
# 75%       13.000000     15.000000      4.000000     40.759718    -73.846150
# max     1887.000000   1906.000000     54.000000     40.912745    -73.700488
#
#             landuse  building_age
# count  34436.000000  34439.000000
# mean       1.943112     83.992421
# std        1.345451     28.985203
# min        1.000000      0.000000
# 25%        1.000000     65.000000
# 50%        1.000000     90.000000
# 75%        3.000000    105.000000
# max       11.000000    225.000000

# %%
df = df.rename(columns={
    "borough_y": "borough",
    "sale_price": "price"
})

# %%
df = df.drop(columns= ["borough_x"])

# %%
df.columns
# Out:
# Index(['block', 'lot', 'price', 'zip_code', 'borough', 'yearbuilt', 'lotarea',
#        'bldgarea', 'resarea', 'comarea', 'unitsres', 'unitstotal', 'numfloors',
#        'latitude', 'longitude', 'landuse', 'bldgclass', 'building_age'],
#       dtype='object')

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# comarea         188
# resarea         188
# numfloors        43
# zip_code         16
# longitude         6
# latitude          6
# landuse           3
# unitsres          0
# bldgclass         0
# unitstotal        0
# block             0
# lot               0
# bldgarea          0
# lotarea           0
# yearbuilt         0
# borough           0
# price             0
# building_age      0
# dtype: int64

# %%
df.duplicated().sum() #The original CSV had 1003 duplicated data
# Out:
# np.int64(1003)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (33436, 18)

# %%
df["price"].describe()
# Out:
# count    3.343600e+04
# mean     1.164029e+06
# std      1.224931e+06
# min      1.186300e+04
# 25%      5.234582e+05
# 50%      8.250000e+05
# 75%      1.290000e+06
# max      9.995000e+06
# Name: price, dtype: float64

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
sns.stripplot(x=df['price'], color='orange')
plt.title("Price Distribution and Outlier Detection")

plt.savefig("../reports/figures/price_outliers_detection.png")
plt.show()

# %%
(df["price"] <= 0).sum()
# Out:
# np.int64(0)

# %%
df["price"].sort_values(ascending=False).head(10)
# Out:
# 4694    9995000
# 5785    9995000
# 1571    9962377
# 1570    9962377
# 1574    9962377
# 1573    9962377
# 1603    9962377
# 1572    9962377
# 1602    9962377
# 4663    9950000
# Name: price, dtype: int64

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\samuel\desktop\curso-analisis-datos-vacio\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Price Distribution Analysis
#
# The following visualizations explore how housing prices are distributed across the dataset in order to identify potential outliers and overall market dispersion.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.hist(df["price"], bins=50)
plt.title("Distribution of Housing Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")

plt.savefig("../reports/figures/distribution_prices.png")

# %%
df["borough"].value_counts()
# Out:
# borough
# QN    12770
# BK     9673
# SI     3897
# MN     3814
# BX     3282
# Name: count, dtype: int64

# %% [markdown]
# ## Housing Sales by Location Category
#
# The following visualization shows how housing sales vary across different location categories, highlighting differences in transaction volume by geographical area.

# %%
import matplotlib.pyplot as plt

df["borough"].value_counts().plot(kind="bar", figsize=(8,4))
plt.title("Number of Housing Sales by Location Category")
plt.xlabel("Location Category")
plt.ylabel("Number of Sales")
plt.xticks(rotation=45)

plt.savefig("../reports/figures/sales_by_location.png")
plt.show()

# %%
df.groupby("borough")["price"].median().sort_values()
# Out:
# borough
# BX    730000.0
# SI    765000.0
# QN    790000.0
# MN    880500.0
# BK    960000.0
# Name: price, dtype: float64

# %%
df["price_per_sqft"] = df["price"] / df["bldgarea"]

df.groupby("borough")["price_per_sqft"].median().sort_values()
# Out:
# borough
# MN     11.275742
# BX    318.074961
# BK    415.331140
# QN    451.726573
# SI    458.333333
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# ## SQL-Based Market Analysis
#
# To validate key market insights, the cleaned dataset was stored in a local SQLite database and analyzed using SQL queries focused on transaction volume and pricing by location category.

# %%
import sqlite3

conn = sqlite3.connect("../sql/nyc_housing.db")
df.to_sql("housing", conn, if_exists = "replace", index = False)
# Out:
# 33436

# %%
pd.read_sql_query("SELECT COUNT(*) FROM housing;", conn)
# Out:
#    COUNT(*)
# 0     33436

# %%
query = """
SELECT borough, COUNT(*) AS number_of_sales
FROM housing
GROUP BY borough
ORDER BY number_of_sales DESC;
"""

pd.read_sql_query(query, conn)
# Out:
#   borough  number_of_sales
# 0      QN            12770
# 1      BK             9673
# 2      SI             3897
# 3      MN             3814
# 4      BX             3282

# %%
pd.read_sql_query("PRAGMA table_info(housing)",conn)
# Out:
#     cid            name     type  notnull dflt_value  pk
# 0     0           block  INTEGER        0       None   0
# 1     1             lot  INTEGER        0       None   0
# 2     2           price  INTEGER        0       None   0
# 3     3        zip_code     REAL        0       None   0
# 4     4         borough     TEXT        0       None   0
# 5     5       yearbuilt     REAL        0       None   0
# 6     6         lotarea     REAL        0       None   0
# 7     7        bldgarea     REAL        0       None   0
# 8     8         resarea     REAL        0       None   0
# 9     9         comarea     REAL        0       None   0
# 10   10        unitsres     REAL        0       None   0
# 11   11      unitstotal     REAL        0       None   0
# 12   12       numfloors     REAL        0       None   0
# 13   13        latitude     REAL        0       None   0
# 14   14       longitude     REAL        0       None   0
# 15   15         landuse     REAL        0       None   0
# 16   16       bldgclass     TEXT        0       None   0
# 17   17    building_age     REAL        0       None   0
# 18   18  price_per_sqft     REAL        0       None   0
